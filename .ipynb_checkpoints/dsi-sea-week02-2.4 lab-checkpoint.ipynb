# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("assets/datasets/billboard.csv")

# %%
print df.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week     ...      \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0     ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0     ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0     ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0     ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0     ...
#
# ...

# %%
# df describe provides a good overall summery of the numerical values in the data frame.
# it shows some detail including count, mean, min/max, standard deviation, and quartiles

df.describe()
# Out:
# /Users/work/anaconda/lib/python2.7/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#          year   x1st.week   x2nd.week   x3rd.week   x4th.week   x5th.week  \
# count   317.0  317.000000  312.000000  307.000000  300.000000  292.000000
# mean   2000.0   79.958991   71.173077   65.045603   59.763333   56.339041
# std       0.0   14.686865   18.200443   20.752302   22.324619   23.780022
# min    2000.0   15.000000    8.000000    6.000000    5.000000    2.000000
# 25%    2000.0   74.000000         NaN         NaN         NaN         NaN
# 50%    2000.0   81.000000         NaN         NaN         NaN         NaN
# 75%    2000.0   91.000000         NaN         NaN         NaN         NaN
# max    2000.0  100.000000  100.000000  100.000000  100.000000  100.000000
#
#         x6th.week   x7th.week   x8th.week   x9th.week     ...      x67th.week  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 83 columns):
# year               317 non-null int64
# artist.inverted    317 non-null object
# track              317 non-null object
# time               317 non-null object
# genre              317 non-null object
# date.entered       317 non-null object
# date.peaked        317 non-null object
# x1st.week          317 non-null int64
# x2nd.week          312 non-null float64
# x3rd.week          307 non-null float64
# x4th.week          300 non-null float64
# x5th.week          292 non-null float64
# x6th.week          280 non-null float64
# x7th.week          269 non-null float64
# x8th.week          260 non-null float64
# x9th.week          253 non-null float64
# x10th.week         244 non-null float64
# x11th.week         236 non-null float64
# x12th.week         222 non-null float64
# x13th.week         210 non-null float64
# x14th.week         204 non-null float64
# ...

# %%
# Median: Median ranking for each track.

def median(x):
    for i in df.ix[x, 7:].values:
        print np.nanmedian(i), df.ix[x, 2]
        return
for i in range(317):
    new_func(i)
# Out:
# 78.0 Independent Women Part I
# 15.0 Maria, Maria
# 71.0 I Knew I Loved You
# 41.0 Music
# 57.0 Come On Over Baby (All I Want Is You)
# 59.0 Doesn't Really Matter
# 83.0 Say My Name
# 63.0 Be With You
# 77.0 Incomplete
# 81.0 Amazed
# 82.0 It's Gonna Be Me
# 71.0 What A Girl Wants
# 70.0 Everything You Want
# 84.0 With Arms Wide Open
# 59.0 Try Again
# 60.0 Bent
# 82.0 Thank God I Found You
# 81.0 Breathe
# 72.0 Case Of The Ex (Whatcha Gonna Do)
# 99.0 He Loves U Not
# 63.0 He Wasn't Man Enough
# 77.0 You Sang To Me
# 51.0 Give Me Just One Night (Una Noche)
# 74.0 Jumpin' Jumpin'
# 81.0 Kryptonite
# 74.0 Thong Song
# 50.0 I Turn To You
# 81.0 My Love Is Your Love
# 94.0 I Wanna Know
# 92.0 Get It On.. Tonite
# 42.0 Bye Bye Bye
# 70.0 The Real Slim Shady
# 85.0 Most Girls
# 85.0 Gotta Tell You
# 73.0 Bring It All To Me
# 36.0 Hot Boyz
# 68.0 I Try
# 68.0 This I Promise You
# 76.0 No More
# 74.0 Show Me The Meaning Of Being Lonely
# 85.0 Absolutely (Story Of A Girl)
# ...

# %%
Mean: Average time on chart per genre

gens = []
for i in df['genre']:
    if i not in gens:
        gens.append(i)
def avg_place(gen):
    sum_num = sum(pd.value_counts(df.ix[df['genre'] == gen]['x1st.week']))
    sum_place = sum(df.ix[df['genre'] == gen]['x1st.week'])
    print 'The average place on the Billboard Chart for a', gen, 'track in week 1 was',sum_place / sum_num

for i in gens:
    avg_place(i)
# Out:
# The average place on the Billboard Chart for a Rock track in week 1 was 76
# The average place on the Billboard Chart for a Latin track in week 1 was 73
# The average place on the Billboard Chart for a Country track in week 1 was 82
# The average place on the Billboard Chart for a Rap track in week 1 was 85
# The average place on the Billboard Chart for a Pop track in week 1 was 79
# The average place on the Billboard Chart for a Electronica track in week 1 was 84
# The average place on the Billboard Chart for a Jazz track in week 1 was 89
# The average place on the Billboard Chart for a R&B track in week 1 was 84
# The average place on the Billboard Chart for a Reggae track in week 1 was 72
# The average place on the Billboard Chart for a Gospel track in week 1 was 76

# %%
#Variance 
print np.var(df)
# Out:
# year             0.000000
# x1st.week      215.023555
# x2nd.week      330.194403
# x3rd.week      429.255249
# x4th.week      496.727322
# x5th.week      563.552859
# x6th.week      596.802028
# x7th.week      655.695388
# x8th.week      692.743476
# x9th.week      733.474636
# x10th.week     789.307041
# x11th.week     840.935794
# x12th.week     831.050808
# x13th.week     865.009161
# x14th.week     927.507978
# x15th.week     989.878018
# x16th.week    1011.985509
# x17th.week    1088.974688
# x18th.week    1095.217158
# x19th.week    1083.497863
# x20th.week    1074.373851
# x21st.week     403.042840
# x22nd.week     438.267769
# x23rd.week     325.610677
# x24th.week     336.865784
# x25th.week     341.851108
# x26th.week     356.500000
# x27th.week     376.087990
# x28th.week     252.416667
# x29th.week     220.627500
#                  ...
# x47th.week     218.960000
# x48th.week     160.500000
# x49th.week     193.500000
# x50th.week     257.500000
# ...
